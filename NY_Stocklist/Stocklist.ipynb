# %%
# Scrape the stock symbols from the New York stock exchange website and load them into a dataframe

#Scrape symbols from single web page
#Determine how to navigate the website programmatically
# Store in a dictionary before converting to dataframe
